# %%
# ! pip install pandas

# %% [markdown]
# ### Import Necessary Libraries

# %%
import io
import os
import glob
import pandas as pd
from datetime import datetime, timedelta

curr_date = datetime.now().strftime('%d-%m-%Y')
prev_day = (datetime.now() - timedelta(days=1)).strftime('%d-%m-%Y')

print("Current date:", curr_date)
print("Previous day:", prev_day)
# Out:
# Current date: 20-06-2024
# Previous day: 19-06-2024

# %% [markdown]
# ### Read files into Dataframes

# %%
column_names = ["S/N", "CHANNEL", "SESSION ID", "TRANSACTION TYPE", "RESPONSE", "AMOUNT",
                "TRANSACTION TIME", "ORIGINATOR INSTITUTION", "ORIGINATOR / BILLER",
                "DESTINATION INSTITUTION", "DESTINATION ACCOUNT NAME", "DESTINATION ACCOUNT NO",
                "NARRATION", "PAYMENT REFERENCE", "LAST 12 DIGITS OF SESSION_ID"]

categories = ["BILLING", "CMMS", "EBILLSPAY", "NIBSS_EASY_PAY", "NIBSS_NIP_POS", "NIBSS_NIP_EBILLSPAY",
              "NIP", "NIP DISPUTE", "NIP REVERSAL", "NQR_MERCHANT", "PRODUCTS", "NIBSS_NIP_GSI"]

session = []

dtype_mapping = {5: str, 11: str}

for folder_path in glob.glob("../Files/*/"):
    folder_name = os.path.basename(os.path.normpath(folder_path))
    session.append(folder_name)

dfs = []

# %% [markdown]
# ### Data Cleaning and Transformation

# %%
for session_folder in session:
    print(f"Session Folder: {session_folder}")
    for category in categories:
        file_pattern = f"../Files/{session_folder}/{category}/*outwards successful.csv"
        file_paths = glob.glob(file_pattern)
        # print(f"File pattern for '{category}' under '{session_folder}': {file_pattern}")

        for file_path in file_paths:
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    content = file.read()
                df = pd.read_csv(io.StringIO(content), header=None, skiprows=6, names=column_names, dtype=dtype_mapping)
                df = df.dropna(subset=df.columns[8:15], how='all')
                df = df.drop(df[df.eq(df.columns)].dropna(how='all').index)
                df["TRANSACTION TIME"] = df["TRANSACTION TIME"].str.lstrip("'")
                df["category"] = category
                df["session"] = session_folder
                dfs.append(df)
                # print(f"Appended DataFrame for file: {file_path}")
            except pd.errors.ParserError:
                print(f"Error parsing file: {file_path}. Please check the file structure.")
            except UnicodeDecodeError:
                print(f"Encoding error for file: {file_path}. Attempting to convert to UTF-8...")
                try:
                    with open(file_path, 'r', encoding='latin-1') as file:
                        content = file.read()
                    df = pd.read_csv(io.StringIO(content), header=None, skiprows=6, names=column_names, dtype=dtype_mapping)
                    df = df.dropna(subset=df.columns[8:15], how='all')
                    df = df.drop(df[df.eq(df.columns)].dropna(how='all').index)
                    df["TRANSACTION TIME"] = df["TRANSACTION TIME"].str.lstrip("'")
                    df["category"] = category
                    df["session"] = session_folder
                    dfs.append(df)
                    print(f"Successfully converted and appended DataFrame for file: {file_path}")
                except Exception as e:
                    print(f"Failed to convert file: {file_path}. Error: {str(e)}")

combined_df = pd.concat(dfs, ignore_index=True)
combined_df["S/N"] = range(1, len(combined_df) + 1)
print("Combined DataFrame is ready")
# Out:
# Session Folder: ECOBANK_20240619_055959
# Session Folder: ECOBANK_20240619_085959
# Session Folder: ECOBANK_20240619_095959
# Encoding error for file: ../Files/ECOBANK_20240619_095959/NIP\NIP_050_outwards successful.csv. Attempting to convert to UTF-8...
# Successfully converted and appended DataFrame for file: ../Files/ECOBANK_20240619_095959/NIP\NIP_050_outwards successful.csv
# Session Folder: ECOBANK_20240619_105959
# Session Folder: ECOBANK_20240619_115959
# Session Folder: ECOBANK_20240619_125959
# Session Folder: ECOBANK_20240619_135959
# Session Folder: ECOBANK_20240619_145959
# Session Folder: ECOBANK_20240619_165959
# Session Folder: ECOBANK_20240619_185959
# Session Folder: ECOBANK_20240619_205959
# Session Folder: ECOBANK_20240619_235959
# Encoding error for file: ../Files/ECOBANK_20240619_235959/NIP\NIP_050_outwards successful.csv. Attempting to convert to UTF-8...
# Successfully converted and appended DataFrame for file: ../Files/ECOBANK_20240619_235959/NIP\NIP_050_outwards successful.csv
# Combined DataFrame is ready

# %%
# # Iterate through each folder in the session list
# for session_folder in session:
#     print(f"Session Folder: {session_folder}")
#     for category in categories:
#         file_pattern = f"../Files/{session_folder}/{category}/*outwards successful.csv"
#         file_paths = glob.glob(file_pattern)
#         print(f"File pattern for '{category}' under '{session_folder}': {file_pattern}")

#         for file_path in file_paths:
#             try:
#                 df = pd.read_csv(file_path, header=None, skiprows=6, names=column_names, encoding='utf-8', dtype=dtype_mapping)
#                 df = df.dropna(subset=df.columns[8:15], how='all')
#                 df = df.drop(df[df.eq(df.columns)].dropna(how='all').index)
#                 df["TRANSACTION TIME"] = df["TRANSACTION TIME"].str.lstrip("'")
#                 df["category"] = category
#                 df["session"] = session_folder
#                 dfs.append(df)
#                 print(f"Appended DataFrame for file: {file_path}")
#             except pd.errors.ParserError:
#                 print(f"Error parsing file: {file_path}. Please check the file structure.")
#             except UnicodeDecodeError:
#                 print(f"Encoding error for file: {file_path}. Ignored.")

# combined_df = pd.concat(dfs, ignore_index=True)
# combined_df["S/N"] = range(1, len(combined_df) + 1)
# print("Combined DataFrame is ready")

# %% [markdown]
# ### Display Cleaned Data

# %%
display(combined_df)
# Out:
#            S/N                       CHANNEL                       SESSION ID  \
# 0            1  THIRD-PARTY PAYMENT PLATFORM  '999999240619001356323764028923
# 1            2  THIRD-PARTY PAYMENT PLATFORM  '999999240619024307618012585918
# 2            3  THIRD-PARTY PAYMENT PLATFORM  '999999240619024544356670058686
# 3            4                  MOBILE PHONE  '999999240619010040790943375062
# 4            5                  MOBILE PHONE  '999999240619010043479453851645
# ...        ...                           ...                              ...
# 299832  299833                  MOBILE PHONE  '000010240609152454111305636717
# 299833  299834                  MOBILE PHONE  '000010240609155431111190902400
# 299834  299835                  MOBILE PHONE  '000010240610165549111173757266
# 299835  299836                  MOBILE PHONE  '000010240610213238111098038365
# 299836  299837                  MOBILE PHONE  '000010240611075140111082891027
#
#                      TRANSACTION TYPE                            RESPONSE  \
# 0       Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 1       Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 2       Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 3       Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 4       Fund Transfer (Direct Credit)  Approved or Completed Successfully
# ...                               ...                                 ...
# 299832  Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 299833  Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 299834  Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 299835  Fund Transfer (Direct Credit)  Approved or Completed Successfully
# 299836  Fund Transfer (Direct Credit)  Approved or Completed Successfully
#
#            AMOUNT     TRANSACTION TIME ORIGINATOR INSTITUTION  \
# 0          50.00   2024-06-19 00:14:00                ECOBANK
# 1        2000.00   2024-06-19 02:43:10                ECOBANK
# 2        1000.00   2024-06-19 02:45:47                ECOBANK
# 3         812.03   2024-06-19 01:00:44                ECOBANK
# 4       13207.41   2024-06-19 01:00:45                ECOBANK
# ...           ...                  ...                    ...
# 299832  39500.00   2024-06-09 16:24:58                ECOBANK
# 299833   3000.00   2024-06-09 16:54:35                ECOBANK
# 299834   9700.00   2024-06-10 17:55:53                ECOBANK
# 299835  10000.00   2024-06-10 22:32:42                ECOBANK
# 299836   1400.00   2024-06-11 08:51:45                ECOBANK
#
#                   ORIGINATOR / BILLER DESTINATION INSTITUTION  \
# 0       ANIFOWOSE TAWAKALITU KIKELOMO               WEMA BANK
# 1           ADENIYAN ADETUTU BLESSING               WEMA BANK
# 2             OMOREGBEE WINNIE EDUGIE               WEMA BANK
# 3               ABRAHAM DESTINY SIMON             ZENITH BANK
# 4                        NATHAN TSAGA             ZENITH BANK
# ...                               ...                     ...
# 299832             MUSBAHU USMAN BALA                  GTBANK
# 299833              ONYINYE UMEONYIDO                  GTBANK
# 299834                 IGWEMOH LILIAN                  GTBANK
# 299835               OLADIMEJI LATEEF                  GTBANK
# 299836                  JOSEPH BINUYO                  GTBANK
#
#                         DESTINATION ACCOUNT NAME DESTINATION ACCOUNT NO  \
# 0       PAYSTACK DIRECT DEBIT COLLECTION ACCOUNT             1300011066
# 1       PAYSTACK DIRECT DEBIT COLLECTION ACCOUNT             1300011066
# 2       PAYSTACK DIRECT DEBIT COLLECTION ACCOUNT             1300011066
# 3                        NEWEDGE FINANCE LID NIP             1223458380
# 4                        NEWEDGE FINANCE LID NIP             1223458380
# ...                                          ...                    ...
# 299832                               BELLO KABIR             0426421404
# 299833                ANYAEGBU CHIDINMA PRECIOUS             0237334122
# 299834                     IGWEMOH LILIAN LADIDI             0695269204
# 299835                   LATEEF OLADIMEJI HAKEEM             7089823709
# 299836                  BALOGUN MONSURAT OLABISI             8139431248
#
#                                                 NARRATION  \
# 0                    TRF-PAYSTACK-DIRECT-DEBIT-3511260319
# 1                    TRF-PAYSTACK-DIRECT-DEBIT-4263005818
# 2                    TRF-PAYSTACK-DIRECT-DEBIT-4400000562
# 3                   Payment to 1223458380 from 2341243998
# 4                   Payment to 1223458380 from 2621202369
# ...                                                   ...
# 299832   REFNGA1378446199 BO MUSBAHU USMAN BALA IFO BELLO
# 299833  REFNGA1378509329 BO ONYINYE UMEONYIDO IFO ANYAEGB
# 299834  REFNGA1381039483 BO IGWEMOH LILIAN IFO IGWEMOH LI
# 299835  REFNGA1381682008 BO OLADIMEJI LATEEF IFO LATEEF O
# 299836  REFNGA1382127570 BO JOSEPH BINUYO IFO BALOGUN MON
#
#                                         PAYMENT REFERENCE  \
# 0       'NIPMINI/110006240619001355000000979454/PSTK/T...
# 1       'NIPMINI/110006240619024306000000979983/PSTK/T...
# 2       'NIPMINI/110006240619024543000000980001/PSTK/T...
# 3       'NIPMINI/050004240619010040144127660041/xc7234...
# 4       'NIPMINI/050004240619010042153749397533/xc7234...
# ...                                                   ...
# 299832                                     'NGA1378446199
# 299833                                     'NGA1378509329
# 299834                                     'NGA1381039483
# 299835                                     'NGA1381682008
# 299836                                     'NGA1382127570
#
#        LAST 12 DIGITS OF SESSION_ID        category                  session
# 0                     '323764028923  NIBSS_EASY_PAY  ECOBANK_20240619_055959
# 1                     '618012585918  NIBSS_EASY_PAY  ECOBANK_20240619_055959
# 2                     '356670058686  NIBSS_EASY_PAY  ECOBANK_20240619_055959
# 3                     '790943375062  NIBSS_EASY_PAY  ECOBANK_20240619_055959
# 4                     '479453851645  NIBSS_EASY_PAY  ECOBANK_20240619_055959
# ...                             ...             ...                      ...
# 299832                '111305636717    NIP REVERSAL  ECOBANK_20240619_235959
# 299833                '111190902400    NIP REVERSAL  ECOBANK_20240619_235959
# 299834                '111173757266    NIP REVERSAL  ECOBANK_20240619_235959
# 299835                '111098038365    NIP REVERSAL  ECOBANK_20240619_235959
# 299836                '111082891027    NIP REVERSAL  ECOBANK_20240619_235959
#
# [299837 rows x 17 columns]

# %% [markdown]
# ### Write Data back into the Output Directory

# %%
output_dir = f"../Output/{prev_day}"
os.makedirs(output_dir, exist_ok=True)

# %%
output_file_path = os.path.join(output_dir, f"Outwards successful_{prev_day}.csv")
# output_file_path = os.path.join(output_dir, f"Outwards successful_17-05-2024.csv")
combined_df.to_csv(output_file_path, index=False, mode='w')

print(f"Output file saved to: {output_file_path}")
# Out:
# Output file saved to: ../Output\Outwards successful_19-06-2024.csv
